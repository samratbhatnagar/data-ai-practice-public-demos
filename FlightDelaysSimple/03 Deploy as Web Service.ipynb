# %% [markdown]
# #Install the Azure ML SDK on your Azure Databricks Cluster

# %% [markdown]
# The `Azure Machine Learning Python SDK` is required for leveraging the experimentation, model management and model deployment capabilities of Azure Machine Learning services.
#
# If your cluster is not already provisioned with the Azure Machine Learning Python SDK, you easily add it to your cluster by adding the following libraries.
#
# For reference, to use this notebook in your own Databricks environment, you will need to create libraries, using the [Create Library](https://docs.azuredatabricks.net/user-guide/libraries.html) interface in Azure Databricks, for the following and attach them to your cluster:
#
# **azureml-sdk**
# * Source: Upload Python Egg or PyPi
# * PyPi Name: `azureml-sdk[databricks]`
# * Select Install Library

# %% [markdown]
# Verify that the Azure ML SDK is installed on your cluster by running the following cell:

# %%
import azureml.core
azureml.core.VERSION
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>&apos;0.1.65&apos;
# </div>

# %% [markdown]
# If you see a version number output in the above cell, your cluster is ready to go.

# %% [markdown]
# #Initialize Azure ML Workspace
#
# In this notebook, you will use the Azure Machine Learning SDK to create a new Azure Machine Learning Workspace in your Azure Subscription.
#
# Please specify the Azure subscription Id, resource group name, workspace name, and the region in which you want to create the Azure Machine Learning Workspace.
#
# You can get the value of your Azure subscription ID from the Azure Portal, and then selecting Subscriptions from the menu on the left.
#
# For the `resource_group`, use the name of the resource group that contains your Azure Databricks Workspace.
#
# NOTE: If you provide a resource group name that does not exist, the resource group will be automatically created. This may or may not succeed in your environment, depending on the permissions you have on your Azure Subscription.

# %%
#Provide the Subscription ID of your existing Azure subscription
subscription_id = "e223f1b3-d19b-4cfa-98e9-bc9be62717bc"#"<you-azure-subscription-id>"

#Provide a name for the new Resource Group that will contain Azure ML related services 
resource_group = "cc-zst-aml2"#"<resource-group-name>"

# Proivde the name and region for the Azure Machine Learning Workspace that will be created
workspace_name = "azure-ml-ws-zst2"#"<azure-ml-workspace-name>"
workspace_region = "westcentralus"#'eastus2' # eastus, westcentralus, southeastasia, australiaeast, westeurope
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Create an Azure ML Workspace

# %% [markdown]
# Run the following cell and follow the instructions printed in the output.
#
# You will see instructions that read:
#
# `Performing interactive authentication. Please follow the instructions on the terminal.`
#
# `To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code SOMECODE to authenticate.`
#
# When you see this, open a new browser window, navigate to the provided URL. At the code prompt, enter the code provided (be sure to delete any trailing spaces).
#
# Login with the same credentials you use to access your Azure subscription.
#
# Once you have authenticated, the output will continue.
#
# When you see `Provisioning complete.` your Workspace has been created and you can move on to the next cell.

# %%
import azureml.core

# import the Workspace class and check the azureml SDK version
from azureml.core import Workspace

ws = Workspace.create(
    name = workspace_name,
    subscription_id = subscription_id,
    resource_group = resource_group, 
    location = workspace_region)

print("Provisioning complete.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code BWS6J2WSC to authenticate.
# Paging async iterator protocol is not available for TenantIdDescriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Paging async iterator protocol is not available for SubscriptionPaged
# Interactive authentication successfully completed.
# UserWarning: The resource group doesn&apos;t exist or was not provided. AzureML SDK is creating a resource group=cc-zst-aml2 in location=westcentralus using subscription=e223f1b3-d19b-4cfa-98e9-bc9be62717bc.
# Provisioning complete.
# </div>

# %% [markdown]
# #Persist the Workspace configuration

# %% [markdown]
# Run the following cells to retrieve the configuration of the deployed Workspace and persist it to local disk and then to the Databricks Filesystem.

# %%
import os
import shutil

ws = Workspace(
    workspace_name = workspace_name,
    subscription_id = subscription_id,
    resource_group = resource_group)

# persist the subscription id, resource group name, and workspace name in aml_config/config.json.
aml_config = 'aml_config'
if os.path.isfile(aml_config) or os.path.isdir(aml_config):
    shutil.rmtree(aml_config)
ws.write_config()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote the config file config.json to: /databricks/driver/aml_config/config.json
# </div>

# %% [markdown]
# Take a look at the contents of the generated configuration file by running the following cell:

# %%
# %sh
cat /databricks/driver/aml_config/config.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{
#     &quot;resource_group&quot;: &quot;cc-zst-aml2&quot;,
#     &quot;workspace_name&quot;: &quot;azure-ml-ws-zst2&quot;,
#     &quot;subscription_id&quot;: &quot;e223f1b3-d19b-4cfa-98e9-bc9be62717bc&quot;
# }</div>

# %% [markdown]
# Copy the config file to DBFS

# %%
#persist the config file to dbfs so that it can be used for the other notebooks.
aml_config_local = 'file:' + os.getcwd() + '/' + aml_config
aml_config_dbfs = '/dbfs/' + 'aml_config'

if os.path.isfile(aml_config_dbfs) or os.path.isdir(aml_config_dbfs):
    shutil.rmtree(aml_config_dbfs)
    #dbutils.fs.rm(aml_config, recurse=True)

dbutils.fs.cp(aml_config_local, aml_config, recurse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>True
# </div>

# %% [markdown]
# #Deploy model to Azure Container Instance (ACI)

# %% [markdown]
# In this notebook, you will deploy the best performing model you selected previously as a web service hosted in Azure Container Service.

# %%
import os
#import urllib
#import pandas as pd

from pyspark.ml import PipelineModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Copy the model from DBFS

# %% [markdown]
# You previously saved the model in DBFS, but to deploy it using Azure Machine Learning services, you will need to copy the model to local storage on the driver node.
#
# Run the following cells to copy the model from DBFS to local and verify that you can load the model.

# %%
##NOTE: service deployment always gets the model from the current working dir. 
model_name = "flightDelayModel"
model_path_dbfs = "/flightDelayModel/"#os.path.join("/dbfs/models", model_name)
model_path_local = "file:" + os.getcwd() + "/" + model_name + "/"

print("copy model from dbfs {} to local {}".format(model_path_dbfs, model_path_local))
dbutils.fs.cp(model_path_dbfs, model_path_local, recurse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">copy model from dbfs /flightDelayModel/ to local file:/databricks/driver/flightDelayModel/
# <span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>True
# </div>

# %% [markdown]
# # Register the model with Azure Machine Learning

# %% [markdown]
# Begin by loading your Azure Machine Learning Workspace configuration from disk.

# %%
import azureml.core
from azureml.core.workspace import Workspace

#get the config file from dbfs
aml_config = '/aml_config'
dbutils.fs.cp(aml_config, 'file:'+os.getcwd()+aml_config, recurse=True)

ws = Workspace.from_config()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Found the config file in: /databricks/driver/aml_config/config.json
# </div>

# %% [markdown]
# In the following, you register the model file with Azure Machine Learning (which saves a copy of the model in the cloud).

# %%
#Register the model
from azureml.core.model import Model
mymodel = Model.register(model_path = model_name, # this points to a local file or folder in the current working dir
                       model_name = model_name, # this is the name the model is registered with                 
                       description = "Flight Delay Prediction Model",
                       workspace = ws)

print(mymodel.name, mymodel.description, mymodel.version)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2071213003705750&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      4</span>                        model_name <span class="ansiyellow">=</span> model_name<span class="ansiyellow">,</span> <span class="ansired"># this is the name the model is registered with</span><span class="ansiyellow"></span>
# <span class="ansigreen">      5</span>                        description <span class="ansiyellow">=</span> <span class="ansiblue">&quot;Flight Delay Prediction Model&quot;</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 6</span><span class="ansiyellow">                        workspace = ws)
# </span><span class="ansigreen">      7</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      8</span> print<span class="ansiyellow">(</span>mymodel<span class="ansiyellow">.</span>name<span class="ansiyellow">,</span> mymodel<span class="ansiyellow">.</span>description<span class="ansiyellow">,</span> mymodel<span class="ansiyellow">.</span>version<span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/azureml/core/model.py</span> in <span class="ansicyan">register</span><span class="ansiblue">(workspace, model_path, model_name, tags, properties, description)</span>
# <span class="ansigreen">    257</span>         artifact_client<span class="ansiyellow">.</span>upload_artifact_from_path<span class="ansiyellow">(</span>model_tar_path<span class="ansiyellow">,</span> origin<span class="ansiyellow">,</span> container<span class="ansiyellow">,</span> tar_name<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    258</span>         prefix_values <span class="ansiyellow">=</span> <span class="ansiyellow">[</span><span class="ansiyellow">{</span><span class="ansiblue">&apos;prefix&apos;</span><span class="ansiyellow">:</span> <span class="ansiblue">&apos;{}/{}/{}&apos;</span><span class="ansiyellow">.</span>format<span class="ansiyellow">(</span>origin<span class="ansiyellow">,</span> container<span class="ansiyellow">,</span> tar_name<span class="ansiyellow">)</span><span class="ansiyellow">}</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 259</span><span class="ansiyellow">         </span>create_asset_result <span class="ansiyellow">=</span> asset_client<span class="ansiyellow">.</span>create_asset<span class="ansiyellow">(</span>model_name<span class="ansiyellow">,</span> prefix_values<span class="ansiyellow">,</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    260</span>         asset <span class="ansiyellow">=</span> create_asset_result<span class="ansiyellow">.</span>content<span class="ansiyellow"></span>
# <span class="ansigreen">    261</span>         <span class="ansigreen">if</span> isinstance<span class="ansiyellow">(</span>asset<span class="ansiyellow">,</span> bytes<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/azureml/_restclient/assets_client.py</span> in <span class="ansicyan">create_asset</span><span class="ansiblue">(self, model_name, artifact_values, metadata_dict, project_id, run_id, tags, properties)</span>
# <span class="ansigreen">     58</span>                    <span class="ansiblue">&quot;meta&quot;</span><span class="ansiyellow">:</span> metadata_dict<span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">     59</span>                    &quot;CreatedTime&quot;: created_time}
# <span class="ansigreen">---&gt; 60</span><span class="ansiyellow">         </span>headers <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_client<span class="ansiyellow">.</span>_client<span class="ansiyellow">.</span>creds<span class="ansiyellow">.</span>get_authentication_header<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     61</span>         self._logger.debug(&quot;Create Asset url: {}\nPayload: {}&quot;.format(
# <span class="ansigreen">     62</span>             create_asset_url, str(payload)))
#
# <span class="ansired">AttributeError</span>: &apos;ServiceClient&apos; object has no attribute &apos;creds&apos;</div>

# %% [markdown]
# ## PoC Challenge
# Can you show Margie's Travel the model you just registered in the `Azure Machine Learning service workspace` in the Azure Portal?

# %% [markdown]
# #Create the scoring web service

# %% [markdown]
# When deploying models for scoring with Azure Machine Learning services, you need to define the code for a simple web service that will load your model and use it for scoring. By convention this service has two methods `init` which loads the model and `run` which scores data using the loaded model.
#
# This scoring service code will later be deployed inside of a specially prepared Docker container.

# %%
#%%writefile score_sparkml.py
score_sparkml = """

import json

def init():
    try:
        # One-time initialization of PySpark and predictive model
        import pyspark
        from pyspark.ml import PipelineModel
        from azureml.core.model import Model
        
        global trainedModel
        global spark
        
        spark = pyspark.sql.SparkSession.builder.appName("Scoring").getOrCreate()
      
        model_name = "flightDelayModel" 
        
        model_path = Model.get_model_path(model_name)

        trainedModel = PipelineModel.load(model_path)

    except Exception as e:
        print("Exception in init: " + str(e))
        trainedModel = e

def run(input_df):
    response = ''    

    if isinstance(trainedModel, Exception):
        return json.dumps({"Exception":trainedModel})

    try:
        print("received: " + input_df)
        
        sc = spark.sparkContext
      
        # Set inferSchema=true to prevent the float values from being seen as strings
        # which can later cause the VectorAssembler to throw an error: 'Data type StringType is not supported.'
        df = spark.read.option("inferSchema", "true").json(sc.parallelize([input_df]))
      
        #Get prediction results for the dataframe
        score = trainedModel.transform(df)
        predictions = score.collect()
        
        #Get each scored result (prediction and confidence)
        preds = [{"prediction":str(result['prediction']), "confidence":str(result['probability'])} for result in predictions]
        
        response = json.dumps(preds)
        
        print("response: " + str(response))
        
    except Exception as e:
        print("Exception in run: " + str(e))
        return (str(e))

    # Return results
    return response
    
"""

exec(score_sparkml)

with open("score_sparkml.py", "w") as file:
    file.write(score_sparkml)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Test the scoring script locally and confirm that it works as desired.

# %%
import json

# Create two records for testing the prediction
test_input1 = {"OriginAirportCode":"SAT","Month":5,"DayofMonth":5,"CRSDepHour":13,"DayOfWeek":7,"Carrier":"MQ","DestAirportCode":"ORD","WindSpeed":9,"SeaLevelPressure":30.03,"HourlyPrecip":0}

test_input2 = {"OriginAirportCode":"ATL","Month":2,"DayofMonth":5,"CRSDepHour":8,"DayOfWeek":4,"Carrier":"MQ","DestAirportCode":"MCO","WindSpeed":3,"SeaLevelPressure":31.03,"HourlyPrecip":0}

# test init() in local notebook# test  
init()

# package the inputs into a JSON string and test run() in local notebook
test_inputs = [test_input1, test_input2] 
json_str_test_inputs = json.dumps(test_inputs)
run(json_str_test_inputs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Deprecated, use Run.get_context() instead
# received: [{&quot;HourlyPrecip&quot;: 0, &quot;OriginAirportCode&quot;: &quot;SAT&quot;, &quot;DayofMonth&quot;: 5, &quot;Carrier&quot;: &quot;MQ&quot;, &quot;Month&quot;: 5, &quot;WindSpeed&quot;: 9, &quot;DestAirportCode&quot;: &quot;ORD&quot;, &quot;SeaLevelPressure&quot;: 30.03, &quot;DayOfWeek&quot;: 7, &quot;CRSDepHour&quot;: 13}, {&quot;HourlyPrecip&quot;: 0, &quot;OriginAirportCode&quot;: &quot;ATL&quot;, &quot;DayofMonth&quot;: 5, &quot;Carrier&quot;: &quot;MQ&quot;, &quot;Month&quot;: 2, &quot;WindSpeed&quot;: 3, &quot;DestAirportCode&quot;: &quot;MCO&quot;, &quot;SeaLevelPressure&quot;: 31.03, &quot;DayOfWeek&quot;: 4, &quot;CRSDepHour&quot;: 8}]
# response: [{&quot;confidence&quot;: &quot;[0.4396574759246262,0.5603425240753738]&quot;, &quot;prediction&quot;: &quot;1.0&quot;}, {&quot;confidence&quot;: &quot;[0.6990975199995147,0.3009024800004852]&quot;, &quot;prediction&quot;: &quot;0.0&quot;}]
# <span class="ansired">Out[</span><span class="ansired">70</span><span class="ansired">]: </span>&apos;[{&quot;confidence&quot;: &quot;[0.4396574759246262,0.5603425240753738]&quot;, &quot;prediction&quot;: &quot;1.0&quot;}, {&quot;confidence&quot;: &quot;[0.6990975199995147,0.3009024800004852]&quot;, &quot;prediction&quot;: &quot;0.0&quot;}]&apos;
# </div>

# %% [markdown]
# # Create a Conda dependencies environment file

# %% [markdown]
# Your scoring service can have dependencies install by using a Conda environment file. Items listed in this file will be conda or pip installed within the Docker container that is created and thus be available to your scoring web service logic.

# %%
from azureml.core.conda_dependencies import CondaDependencies 

myacienv = CondaDependencies.create(conda_packages=['scikit-learn','numpy','pandas'])

with open("mydeployenv.yml","w") as f:
    f.write(myacienv.serialize_to_string())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #Deployment

# %% [markdown]
# In the following cells you will use the Azure Machine Learning SDK to package the model and scoring script in a container, and deploy that container to an Azure Container Instance.
#
# Run the following cells.

# %% [markdown]
# Create a configuration of the ACI web service instance that provides the number of CPU cores, size of memory, a collection of tags and a description.

# %%
from azureml.core.webservice import AciWebservice, Webservice

aci_config = AciWebservice.deploy_configuration(
    cpu_cores = 1, 
    memory_gb = 1, 
    tags = {'name':'Flight Delay Prediction'}, 
    description = 'Predicts if a flight will be delayed by 15 minutes or more.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Next, build up a container image configuration that names the scoring service script, the runtime (python or Spark), and provides the conda file.

# %%
service_name = "sparkmlservicedb01"
runtime = "spark-py" #"python" #
driver_file = "score_sparkml.py"
conda_file = "mydeployenv.yml"

from azureml.core.image import ContainerImage

image_config = ContainerImage.image_configuration(execution_script = driver_file,
                                                  runtime = runtime,
                                                  conda_file = conda_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now you are ready to begin your deployment to the Azure Container Instance.
#
# Run the following cell. This may take between **5-15 minutes** to complete.
#
# You will see output similar to the following when your web service is ready:
# `SucceededACI service creation operation finished, operation "Succeeded"`

# %%
webservice = Webservice.deploy_from_model(
  workspace=ws, 
  name=service_name, 
  deployment_config=aci_config,
  models = [mymodel], 
  image_config=image_config, 
  )

webservice.wait_for_deployment(show_output=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Creating image
# Image creation operation finished for image sparkmlservicedb01:2, operation &quot;Succeeded&quot;
# Creating service
# Running.....................................................................
# SucceededACI service creation operation finished, operation &quot;Succeeded&quot;
# </div>

# %% [markdown]
# #Test the deployed service

# %% [markdown]
# Now you are ready to test scoring using the deployed web service. The following cell invokes the web service.
#
# Run the following cells to test scoring using a single input row against the deployed web service.

# %%
webservice.run(input_data = json_str_test_inputs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">71</span><span class="ansired">]: </span>&apos;[{&quot;prediction&quot;: &quot;1.0&quot;, &quot;confidence&quot;: &quot;[0.4396574759246262,0.5603425240753738]&quot;}, {&quot;prediction&quot;: &quot;0.0&quot;, &quot;confidence&quot;: &quot;[0.6990975199995147,0.3009024800004852]&quot;}]&apos;
# </div>

# %% [markdown]
# #Clean up

# %% [markdown]
# When you are finished experimenting with your deployed web service, you can also use the Azure Machine Learning Python SDK to delete the deployed service.
#
# Run the following cell to cleanup.

# %%
webservice.delete()

# %% [markdown]
# # You are done!

# %% [markdown]
# Congratulations, you have completed this team challenge!
